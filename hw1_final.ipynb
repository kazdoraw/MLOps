# %% [markdown]
# # MLOps HW1: ML Pipeline с DVC и MLflow
#
# **Задача**: Бинарная классификация медицинских консультаций
# - Класс 0: Онлайн консультация
# - Класс 1: Требуется офлайн-визит
#
# **GitHub**: https://github.com/kazdoraw/MLOps.git

# %% [markdown]
# ## 1. Установка зависимостей

# %%
# !pip install -q pandas numpy scikit-learn mlflow dvc kagglehub joblib matplotlib seaborn pyyaml
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (3.6.0)
# Requirement already satisfied: mlflow-skinny==3.6.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (3.6.0)
# Requirement already satisfied: mlflow-tracing==3.6.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (3.6.0)
# Requirement already satisfied: Flask-CORS<7 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: Flask<4 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (1.17.2)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (2.5.4)
# Requirement already satisfied: matplotlib<4 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (3.10.7)
# Requirement already satisfied: numpy<3 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (2.1.3)
# Requirement already satisfied: pandas<3 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: scikit-learn<2 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (1.7.2)
# Requirement already satisfied: scipy<2 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (1.16.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow) (2.0.44)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (8.3.0)
# Requirement already satisfied: cloudpickle<4 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.73.0)
# Requirement already satisfied: fastapi<1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.123.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: packaging<26 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (5.29.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.38.0)
# Requirement already satisfied: Mako in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (2.43.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.6.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from matplotlib<4->mlflow) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.6.0->mlflow) (0.59b0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (4.11.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny==3.6.0->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/ml-python312/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.23)

# %% [markdown]
# ## 2. Загрузка датасета ChatDoctor

# %%
import kagglehub
import os
import shutil

os.makedirs("data/raw", exist_ok=True)

path = kagglehub.dataset_download("punyaslokaprusty/chatdoctor")
print(f"Загружено в: {path}")

for file in os.listdir(path):
    if os.path.isfile(os.path.join(path, file)):
        shutil.copy(os.path.join(path, file), "data/raw/")
        print(f"Скопирован: {file}")

print("\nJSON файлы готовы")
# Out:
# Загружено в: /Users/kazdoraw/.cache/kagglehub/datasets/punyaslokaprusty/chatdoctor/versions/1
# Скопирован: HealthCareMagic-100k.json
# Скопирован: iCliniq.json
#
# JSON файлы готовы

# %% [markdown]
# ## 3. Инициализация Git и DVC

# %%
if not os.path.exists('.git'):
    # !git init
else:
    print("Git уже существует")

if not os.path.exists('.dvc'):
    # !dvc init
    # !git add .gitignore .dvc/
    # !git commit -m "Init DVC"
else:
    print("DVC уже существует")
# Out:
# Git уже существует
# DVC уже существует

# %% [markdown]
# ## 4. Подготовка данных
#
# `src/prepare.py`:
# - Парсит JSON → создает chatdoctor.csv
# - Генерирует метки (class_weight будет учтен при обучении)
# - Train/test split

# %%
# !python src/prepare.py
# Out:
# Загрузка существующего CSV: data/raw/chatdoctor.csv
# Загружено записей: 231649
# Распределение меток: {0: 214502, 1: 17147}
#
# После очистки пропусков: 231649
# Распределение меток: {0: 214502, 1: 17147}
# Выбрано записей для обучения: 50000
#
# Сохранено:
#   - train.csv: 40000 записей
#   - test.csv: 10000 записей
#
# Распределение в train: {0: 36985, 1: 3015}
# Распределение в test: {0: 9246, 1: 754}

# %% [markdown]
# ## 5. Обучение модели
#
# `src/train.py`:
# - TF-IDF векторизация
# - RandomForest с **class_weight='balanced'**
# - Логирование в MLflow

# %%
# !python src/train.py
# Out:
# 2025/12/01 00:24:44 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/01 00:24:44 INFO mlflow.store.db.utils: Updating database tables
# 2025-12-01 00:24:44 INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# 2025-12-01 00:24:44 INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2025-12-01 00:24:44 INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# 2025-12-01 00:24:44 INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# Загрузка обработанных данных...
# Train: 40000, Test: 10000
# Распределение классов в train: {0: 36985, 1: 3015}
# Распределение классов в test: {0: 9246, 1: 754}
#
# Обучение модели...
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    1.1s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.0s finished
#
# Метрики на Train:
#   Accuracy:  0.9861
#
# Метрики на Test:
#   Accuracy:  0.9665
#   Precision (weighted): 0.9646
#   Recall (weighted):    0.9665
#   F1-score (weighted):  0.9644
#
# Метрики для класса 1 (офлайн визит):
#   Precision: 0.8631
#   Recall:    0.6605
#   F1-score:  0.7483
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      9246
#            1       0.86      0.66      0.75       754
#
#     accuracy                           0.97     10000
#    macro avg       0.92      0.83      0.87     10000
# weighted avg       0.96      0.97      0.96     10000
#
# Confusion matrix сохранена: models/confusion_matrix.png
# 2025/12/01 00:24:57 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/12/01 00:24:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#
# Модель сохранена: models/model.pkl
# Артефакты залогированы в MLflow

# %% [markdown]
# ## 6. Просмотр результатов (программно)

# %%
import mlflow
import pandas as pd
from IPython.display import display

# Подключаемся к базе данных MLflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")

# Получаем все эксперименты
runs = mlflow.search_runs(
    experiment_names=["chatdoctor_classification"],
    order_by=["start_time DESC"]
)

if runs.empty:
    print("Эксперименты не найдены. Запустите обучение модели.")
else:
    print(f"Найдено экспериментов: {len(runs)}\n")
    
    latest = runs.iloc[0]
    
    print("=" * 60)
    print("РЕЗУЛЬТАТЫ МОДЕЛИ")
    print("=" * 60)
    print(f"\nМодель: {latest.get('params.model_type', 'N/A')}")
    print(f"Дата: {latest['start_time']}")
    
    print("\n" + "-" * 60)
    print("ОБЩИЕ МЕТРИКИ:")
    print("-" * 60)
    print(f"  Accuracy (train):     {latest.get('metrics.accuracy_train', 0):.4f}")
    print(f"  Accuracy (test):      {latest.get('metrics.accuracy_test', 0):.4f}")
    print(f"  Precision (weighted): {latest.get('metrics.precision', 0):.4f}")
    print(f"  Recall (weighted):    {latest.get('metrics.recall', 0):.4f}")
    print(f"  F1-score (weighted):  {latest.get('metrics.f1_score', 0):.4f}")
    
    print("\n" + "-" * 60)
    print("МЕТРИКИ КЛАССА 1 (офлайн-визит):")
    print("-" * 60)
    print(f"  Precision: {latest.get('metrics.precision_class_1', 0):.4f}")
    print(f"  Recall:    {latest.get('metrics.recall_class_1', 0):.4f}")
    print(f"  F1-score:  {latest.get('metrics.f1_score_class_1', 0):.4f}")
    
    print("\n" + "-" * 60)
    print("ПАРАМЕТРЫ:")
    print("-" * 60)
    print(f"  n_estimators:       {latest.get('params.n_estimators', 'N/A')}")
    print(f"  max_depth:          {latest.get('params.max_depth', 'N/A')}")
    print(f"  tfidf_max_features: {latest.get('params.tfidf_max_features', 'N/A')}")
    print("=" * 60)
    
    # Таблица экспериментов
    print("\nВСЕ ЭКСПЕРИМЕНТЫ:")
    cols = ['start_time', 'metrics.accuracy_test', 'metrics.recall_class_1', 'metrics.f1_score_class_1']
    available = [c for c in cols if c in runs.columns]
    if available:
        display(runs[available].head())
    
    print("\nФайлы с результатами:")
    print("   models/confusion_matrix.png")
    print("   models/model.pkl")
# Out:
# Найдено экспериментов: 11
#
# ============================================================
# РЕЗУЛЬТАТЫ МОДЕЛИ
# ============================================================
#
# Модель: RandomForestClassifier
# Дата: 2025-11-30 20:24:45.236000+00:00
#
# ------------------------------------------------------------
# ОБЩИЕ МЕТРИКИ:
# ------------------------------------------------------------
#   Accuracy (train):     0.9861
#   Accuracy (test):      0.9665
#   Precision (weighted): 0.9646
#   Recall (weighted):    0.9665
#   F1-score (weighted):  0.9644
#
# ------------------------------------------------------------
# МЕТРИКИ КЛАССА 1 (офлайн-визит):
# ------------------------------------------------------------
#   Precision: 0.8631
#   Recall:    0.6605
#   F1-score:  0.7483
#
# ------------------------------------------------------------
# ПАРАМЕТРЫ:
# ------------------------------------------------------------
#   n_estimators:       100
#   max_depth:          15
#   tfidf_max_features: 5000
# ============================================================
#
# ВСЕ ЭКСПЕРИМЕНТЫ:
#                         start_time  metrics.accuracy_test  \
# 0 2025-11-30 20:24:45.236000+00:00                 0.9665
# 1 2025-11-30 20:16:52.281000+00:00                 0.9665
# 2 2025-11-30 20:14:35.824000+00:00                 0.9665
# 3 2025-11-30 20:08:31.100000+00:00                 0.9665
# 4 2025-11-30 20:05:27.972000+00:00                 0.9665
#
#    metrics.recall_class_1  metrics.f1_score_class_1
# 0                0.660477                   0.74831
# 1                0.660477                   0.74831
# 2                0.660477                   0.74831
# 3                0.660477                   0.74831
# 4                0.660477                   0.74831
# Файлы с результатами:
#    models/confusion_matrix.png
#    models/model.pkl

# %% [markdown]
# ## Запуск MLflow UI (Web-интерфейс)

# %%
import subprocess
import socket
import time
from IPython.display import display, HTML, IFrame

# Используем порт 5001 вместо 5000 (5000 занят системой)
MLFLOW_PORT = 5001
MLFLOW_URL = f"http://127.0.0.1:{MLFLOW_PORT}"

def is_port_open(port):
    """Проверка, запущен ли сервер на порту"""
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    result = sock.connect_ex(('127.0.0.1', port))
    sock.close()
    return result == 0

def check_mlflow_health(port):
    """Проверка, что MLflow UI отвечает"""
    import urllib.request
    try:
        urllib.request.urlopen(f'http://127.0.0.1:{port}/', timeout=2)
        return True
    except:
        return False

if is_port_open(MLFLOW_PORT) and check_mlflow_health(MLFLOW_PORT):
    print(f"MLflow UI запущен на {MLFLOW_URL}\n")
    
    display(HTML(f'''
        <a href="{MLFLOW_URL}" target="_blank" 
           style="display: inline-block; padding: 15px 30px; font-size: 18px; 
                  background-color: #0194E2; color: white; text-decoration: none; 
                  border-radius: 5px; font-weight: bold; margin: 10px 0;">
            Открыть MLflow UI
        </a>
    '''))
    
    print("\nMLflow UI (встроенный):")
    display(IFrame(src=MLFLOW_URL, width=1000, height=600))
    
else:
    print(f"MLflow UI НЕ запущен на порту {MLFLOW_PORT}\n")
    print("ЗАПУСК:\n")
    print("В терминале выполните:")
    print("   cd /Users/Shared/ml/DEPLOY/HW1")
    print("   ./start_mlflow.sh")
    print(f"\nЗатем откройте: {MLFLOW_URL}")
# Out:
# MLflow UI запущен на http://127.0.0.1:5001
#         <a href="http://127.0.0.1:5001" target="_blank"
#            style="display: inline-block; padding: 15px 30px; font-size: 18px;
#                   background-color: #0194E2; color: white; text-decoration: none;
#                   border-radius: 5px; font-weight: bold; margin: 10px 0;">
#             Открыть MLflow UI
#         </a>
# MLflow UI (встроенный):
#         <iframe
#             width="1000"
#             height="600"
#             src="http://127.0.0.1:5001"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
